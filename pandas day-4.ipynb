# %%
import pandas as pd

# %%
df = pd.read_csv("files/placement - placement.csv")

# %%
df
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
# x = df.astype(int)  ## used for type conversion
df['cgpa'] = df['cgpa'].astype(int)

# %%
df.head()
# Out:
#    cgpa  resume_score  placed
# 0     8          6.52       1
# 1     6          5.17       0
# 2     8          8.86       1
# 3     6          7.27       1
# 4     7          7.30       1

# %%
df['resume_score'] = df['resume_score'].astype(int)

# %%
df.head(5)
# Out:
#    cgpa  resume_score  placed
# 0  8.14             6       1
# 1  6.17             5       0
# 2  8.27             8       1
# 3  6.88             7       1
# 4  7.52             7       1

# %%
# to add the value in column 
df['cgpa'] = df['cgpa'].add(10)

# %%
df
# Out:
#      cgpa  resume_score  placed
# 0   18.14             6       1
# 1   16.17             5       0
# 2   18.27             8       1
# 3   16.88             7       1
# 4   17.52             7       1
# ..    ...           ...     ...
# 95  16.33             6       0
# 96  18.23             7       1
# 97  16.65             7       0
# 98  18.14             5       1
# 99  16.09             6       0
#
# [100 rows x 3 columns]

# %%
# mean of the column 
r = df['cgpa'].mean()

# %%
r
# Out:
# np.float64(16.942200000000003)

# %%
s = df['cgpa'].median()
s
# Out:
# np.float64(16.619999999999997)

# %%
# filter in pandas
g  = df.filter(items = ['cgpa','placed'])
g
df[['cgpa' , 'placed']]
# Out:
#     cgpa  placed
# 0   8.14       1
# 1   6.17       0
# 2   8.27       1
# 3   6.88       1
# 4   7.52       1
# ..   ...     ...
# 95  6.33       0
# 96  8.23       1
# 97  6.65       0
# 98  8.14       1
# 99  6.09       0
#
# [100 rows x 2 columns]

# %%
# axis = 0 --> means row wise operration 
s = df.filter(items = [5,6] , axis = 0)
s
# Out:
#     cgpa  resume_score  placed
# 5  18.77             6       1
# 6  15.34             7       0

# %%
s = df.to_dict()  # save in dictionary format
s
# Out:
# {'cgpa': {0: 18.14,
#   1: 16.17,
#   2: 18.27,
#   3: 16.88,
#   4: 17.52,
#   5: 18.77,
#   6: 15.34,
#   7: 16.56,
#   8: 16.32,
#   9: 17.69,
#   10: 16.18,
#   11: 15.440000000000001,
#   12: 16.09,
#   13: 18.5,
#   14: 17.509999999999998,
#   15: 18.880000000000003,
#   16: 18.04,
#   17: 17.81,
#   18: 15.940000000000001,
#   19: 16.75,
#   20: 15.8,
#   21: 16.53,
#   22: 16.16,
#   23: 16.05,
#   24: 18.22,
#   25: 17.759999999999998,
#   26: 16.27,
#   27: 15.51,
#   28: 17.46,
#   29: 16.19,
#   30: 17.36,
#   31: 15.92,
#   32: 15.870000000000001,
#   33: 18.43,
#   34: 18.869999999999997,
#   35: 18.07,
#   36: 18.16,
#   37: 19.05,
#   38: 16.0,
#   39: 17.5,
#   40: 18.25,
#   41: 18.68,
#   42: 16.9,
#   43: 18.21,
#   44: 15.469999999999999,
#   45: 18.1,
#   46: 15.83,
#   47: 17.05,
#   48: 15.54,
#   49: 15.46,
#   50: 18.22,
#   51: 16.54,
#   52: 15.9,
#   53: 16.0,
#   54: 15.92,
#   55: 16.94,
#   56: 16.13,
#   57: 16.34,
#   58: 16.47,
#   59: 15.95,
# ...

# %%
q = df.to_string()  # save in string format

# %%
idx = df.columns 
idx
# Out:
# Index(['cgpa', 'resume_score', 'placed'], dtype='object')

# %%
label = df.columns[0]  #first column label
label
# Out:
# 'cgpa'

# %%
p = df.columns.tolist()  # list of column labels 
p
# Out:
# ['cgpa', 'resume_score', 'placed']

# %%
# reaname a coloumn 
p = df.rename(columns={'cgpa': 'updated_cgpa', 'resume_score' : 'semester_marks'})
p
# Out:
#     updated_cgpa  semester_marks  placed
# 0           8.14            6.52       1
# 1           6.17            5.17       0
# 2           8.27            8.86       1
# 3           6.88            7.27       1
# 4           7.52            7.30       1
# ..           ...             ...     ...
# 95          6.33            6.38       0
# 96          8.23            7.76       1
# 97          6.65            7.78       0
# 98          8.14            5.63       1
# 99          6.09            6.61       0
#
# [100 rows x 3 columns]

# %%
df['half'] = df['cgpa'].where(df['cgpa']>7 , other = 0)
df.head(5)
# Out:
#    cgpa  resume_score  placed  half
# 0  8.14          6.52       1  8.14
# 1  6.17          5.17       0  0.00
# 2  8.27          8.86       1  8.27
# 3  6.88          7.27       1  0.00
# 4  7.52          7.30       1  7.52

# %%
df = pd.read_csv("tips - tips.csv")

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
p = df.iloc[11:14]
p
# Out:
#     total_bill   tip     sex smoker  day    time  size
# 11       35.26  5.00  Female     No  Sun  Dinner     4
# 12       15.42  1.57    Male     No  Sun  Dinner     2
# 13       18.43  3.00    Male     No  Sun  Dinner     4

# %%
p = df.iloc[:,[2]]
p
# Out:
#         sex
# 0    Female
# 1      Male
# 2      Male
# 3      Male
# 4    Female
# ..      ...
# 239    Male
# 240  Female
# 241    Male
# 242    Male
# 243  Female
#
# [244 rows x 1 columns]

# %%
p = df.rename(columns={'total_bill': 'bill', 'sex' : 'gender'})
p
# Out:
#       bill   tip  gender smoker   day    time  size
# 0    16.99  1.01  Female     No   Sun  Dinner     2
# 1    10.34  1.66    Male     No   Sun  Dinner     3
# 2    21.01  3.50    Male     No   Sun  Dinner     3
# 3    23.68  3.31    Male     No   Sun  Dinner     2
# 4    24.59  3.61  Female     No   Sun  Dinner     4
# ..     ...   ...     ...    ...   ...     ...   ...
# 239  29.03  5.92    Male     No   Sat  Dinner     3
# 240  27.18  2.00  Female    Yes   Sat  Dinner     2
# 241  22.67  2.00    Male    Yes   Sat  Dinner     2
# 242  17.82  1.75    Male     No   Sat  Dinner     2
# 243  18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df['Male_customer'] = df['sex'].where(df['sex']=='Male' , other = 0)
df
# Out:
#      total_bill   tip     sex smoker   day    time  size Male_customer
# 0            16  1.01  Female     No   Sun  Dinner     2             0
# 1            10  1.66    Male     No   Sun  Dinner     3          Male
# 2            21  3.50    Male     No   Sun  Dinner     3          Male
# 3            23  3.31    Male     No   Sun  Dinner     2          Male
# 4            24  3.61  Female     No   Sun  Dinner     4             0
# ..          ...   ...     ...    ...   ...     ...   ...           ...
# 239          29  5.92    Male     No   Sat  Dinner     3          Male
# 240          27  2.00  Female    Yes   Sat  Dinner     2             0
# 241          22  2.00    Male    Yes   Sat  Dinner     2          Male
# 242          17  1.75    Male     No   Sat  Dinner     2          Male
# 243          18  3.00  Female     No  Thur  Dinner     2             0
#
# [244 rows x 8 columns]

# %%
df['total_bill'] = df['total_bill'].astype(int)
df
# Out:
#      total_bill   tip     sex smoker   day    time  size Male_customer
# 0            16  1.01  Female     No   Sun  Dinner     2             0
# 1            10  1.66    Male     No   Sun  Dinner     3          Male
# 2            21  3.50    Male     No   Sun  Dinner     3          Male
# 3            23  3.31    Male     No   Sun  Dinner     2          Male
# 4            24  3.61  Female     No   Sun  Dinner     4             0
# ..          ...   ...     ...    ...   ...     ...   ...           ...
# 239          29  5.92    Male     No   Sat  Dinner     3          Male
# 240          27  2.00  Female    Yes   Sat  Dinner     2             0
# 241          22  2.00    Male    Yes   Sat  Dinner     2          Male
# 242          17  1.75    Male     No   Sat  Dinner     2          Male
# 243          18  3.00  Female     No  Thur  Dinner     2             0
#
# [244 rows x 8 columns]

# %%
df.dtypes
# Out:
# total_bill         int64
# tip              float64
# sex               object
# smoker            object
# day               object
# time              object
# size               int64
# Male_customer     object
# dtype: object

# %%
a = df.head(6)
a
# Out:
#    total_bill   tip     sex smoker  day    time  size Male_customer
# 0          16  1.01  Female     No  Sun  Dinner     2             0
# 1          10  1.66    Male     No  Sun  Dinner     3          Male
# 2          21  3.50    Male     No  Sun  Dinner     3          Male
# 3          23  3.31    Male     No  Sun  Dinner     2          Male
# 4          24  3.61  Female     No  Sun  Dinner     4             0
# 5          25  4.71    Male     No  Sun  Dinner     4          Male

# %%
a.to_csv("new_data.csv")

# %%
a.to_excel("new_data1.xlsx")

# %%
df = pd.read_csv("new_data.csv")
df
# Out:
#    Unnamed: 0  total_bill   tip     sex smoker  day    time  size  \
# 0           0          16  1.01  Female     No  Sun  Dinner     2
# 1           1          10  1.66    Male     No  Sun  Dinner     3
# 2           2          21  3.50    Male     No  Sun  Dinner     3
# 3           3          23  3.31    Male     No  Sun  Dinner     2
# 4           4          24  3.61  Female     No  Sun  Dinner     4
# 5           5          25  4.71    Male     No  Sun  Dinner     4
#
#   Male_customer
# 0             0
# 1          Male
# 2          Male
# 3          Male
# 4             0
# 5          Male

# %%
# data -->
# numerical --> continuous data --> we can devide furthur.
# salary = 20500.60, weight = 70.54, distance(jaipur to delhi)= 270.78km, height, age 
# categorical --. Descreate data --> we cannot devide further. 
# gender(m,f), marritial status(mu), number of employees in an office,

# covid data --> has_covid(y,n) --> map --> (1,0)
# customer cafe --> bill pay --> 453.25 rupees
