# %%
import pandas as pd

# %%
df = pd.read_csv("covid_toy - covid_toy.csv")
df
# Out:
#     age  gender  fever   cough       city has_covid
# 0    60    Male  103.0    Mild    Kolkata        No
# 1    27    Male  100.0    Mild      Delhi       Yes
# 2    42    Male  101.0    Mild      Delhi        No
# 3    31  Female   98.0    Mild    Kolkata        No
# 4    65  Female  101.0    Mild     Mumbai        No
# ..  ...     ...    ...     ...        ...       ...
# 95   12  Female  104.0    Mild  Bangalore        No
# 96   51  Female  101.0  Strong    Kolkata       Yes
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes
#
# [100 rows x 6 columns]

# %%
# top data check , we will use df.head() , by default it returns top 5 rows 
df.head(5)
# Out:
#    age  gender  fever cough     city has_covid
# 0   60    Male  103.0  Mild  Kolkata        No
# 1   27    Male  100.0  Mild    Delhi       Yes
# 2   42    Male  101.0  Mild    Delhi        No
# 3   31  Female   98.0  Mild  Kolkata        No
# 4   65  Female  101.0  Mild   Mumbai        No

# %%
# bottom data check , we will use df.tail() , by default it gives last 5 rows 
df.tail(5)
# Out:
#     age  gender  fever   cough       city has_covid
# 95   12  Female  104.0    Mild  Bangalore        No
# 96   51  Female  101.0  Strong    Kolkata       Yes
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes

# %%
# if you want random indexed data , then we will use df.sample(). By default it will return single row. 
df.sample()
# Out:
#     age  gender  fever  cough     city  has_covid
# 59    6       1  104.0    0.0  Kolkata          1

# %%
# if we want to check overall information then we will use df.info()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        100 non-null    int64
#  1   gender     100 non-null    int64
#  2   fever      100 non-null    float64
#  3   cough      62 non-null     float64
#  4   city       100 non-null    object
#  5   has_covid  100 non-null    int64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 4.8+ KB

# %%
# if we want to check data types of each column pf each use df.dtypes()
df.dtypes()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # if we want to check data types of each column pf each use df.dtypes()
# ----> 2 df.dtypes()
#
# NameError: name 'df' is not defined

# %%
# if you want to check statical views of data , then you can use df.describe ()

# %%
df.describe()
# Out:
#               age       fever
# count  100.000000   90.000000
# mean    44.220000  100.844444
# std     24.878931    2.054926
# min      5.000000   98.000000
# 25%     20.000000   99.000000
# 50%     45.000000  101.000000
# 75%     66.500000  102.750000
# max     84.000000  104.000000

# %%
df.head(2)
# Out:
#    age gender  fever cough     city has_covid
# 0   60   Male  103.0  Mild  Kolkata        No
# 1   27   Male  100.0  Mild    Delhi       Yes

# %%
# if you want to check missing data in df , then you will use df.isnull().sum()

# %%
df.isnull().sum() ## here fever has 10 missing values
# Out:
# age           0
# gender        0
# fever        10
# cough         0
# city          0
# has_covid     0
# dtype: int64

# %%
# x = 1,2,3,NAN,5 
# mean = (1+2+3+4)/4 = 11/4 = 2.75
# we will this value in this missing data 
# x = 1,2,3,2.75,5

# %%
df['fever'] = df['fever'].fillna(df['fever'].mean())

# %%
df.isnull().sum()
# Out:
# age          0
# gender       0
# fever        0
# cough        0
# city         0
# has_covid    0
# dtype: int64

# %%
df.head(1)
# Out:
#    age gender  fever cough     city has_covid
# 0   60   Male  103.0  Mild  Kolkata        No

# %%
# if you caterigorical data, and you want to check total sub-categories then we will use df['column_name'].value_count()

# %%
df['gender'].value_counts()
# Out:
# gender
# Female    59
# Male      41
# Name: count, dtype: int64

# %%
df['gender'] = df['gender'].map({"Female":1 , "Male":0})

# %%
df.head(5)
# Out:
#    age  gender  fever cough     city has_covid
# 0   60       0  103.0  Mild  Kolkata        No
# 1   27       0  100.0  Mild    Delhi       Yes
# 2   42       0  101.0  Mild    Delhi        No
# 3   31       1   98.0  Mild  Kolkata        No
# 4   65       1  101.0  Mild   Mumbai        No

# %%
df['cough'] =df['cough'].map({"Mild":0 , "Strond":1})

# %%
df.head(5)
# Out:
#    age  gender  fever  cough     city has_covid
# 0   60       0  103.0    0.0  Kolkata        No
# 1   27       0  100.0    0.0    Delhi       Yes
# 2   42       0  101.0    0.0    Delhi        No
# 3   31       1   98.0    0.0  Kolkata        No
# 4   65       1  101.0    0.0   Mumbai        No

# %%
df['has_covid'] = df['has_covid'].map({"No" : 0 , "Yes" : 1})

# %%
df.head(5)
# Out:
#    age  gender  fever  cough     city  has_covid
# 0   60       0  103.0    0.0  Kolkata          0
# 1   27       0  100.0    0.0    Delhi          1
# 2   42       0  101.0    0.0    Delhi          0
# 3   31       1   98.0    0.0  Kolkata          0
# 4   65       1  101.0    0.0   Mumbai          0

# %%
df['city'].value_counts()
# Out:
# city
# Kolkata      32
# Bangalore    30
# Delhi        22
# Mumbai       16
# Name: count, dtype: int64

# %%
df['city'] = df['city'].map({"Kolkata":0 , "Bangalore":1 , "Delhi" : 3 , "Mumbai" : 4 })

# %%
df.head()
# Out:
#    age  gender  fever  cough  city  has_covid
# 0   60       0  103.0    0.0     0          0
# 1   27       0  100.0    0.0     3          1
# 2   42       0  101.0    0.0     3          0
# 3   31       1   98.0    0.0     0          0
# 4   65       1  101.0    0.0     4          0

# %%
df = pd.read_csv("tips - tips.csv")

# %%
df.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df['sex'] = df['sex'].map({"Female" : 1 , "Male" : 0})

# %%
df.head(5)
# Out:
#    total_bill   tip  sex smoker  day    time  size
# 0       16.99  1.01  NaN     No  Sun  Dinner     2
# 1       10.34  1.66  NaN     No  Sun  Dinner     3
# 2       21.01  3.50  NaN     No  Sun  Dinner     3
# 3       23.68  3.31  NaN     No  Sun  Dinner     2
# 4       24.59  3.61  NaN     No  Sun  Dinner     4
