# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('../files/Churn_Modelling - Churn_Modelling.csv')

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
df['Geography'].value_counts()
# Out:
# Geography
# France     5014
# Germany    2509
# Spain      2477
# Name: count, dtype: int64

# %%
df.groupby('Gender')['CreditScore'].mean()
# Out:
# Gender
# Female    650.831389
# Male      650.276892
# Name: CreditScore, dtype: float64

# %%
df['Exited'].value_counts()
# Out:
# Exited
# 0    7963
# 1    2037
# Name: count, dtype: int64

# %%
df.groupby('Geography')['Balance'].mean()
# Out:
# Geography
# France      62092.636516
# Germany    119730.116134
# Spain       61818.147763
# Name: Balance, dtype: float64

# %%
df['Exited'].value_counts()
# Out:
# Exited
# 0    7963
# 1    2037
# Name: count, dtype: int64

# %%
df.groupby('IsActiveMember')['EstimatedSalary'].mean()
# Out:
# IsActiveMember
# 0    100767.203854
# 1     99452.965894
# Name: EstimatedSalary, dtype: float64

# %%
df.groupby('NumOfProducts')['Exited'].sum()
# Out:
# NumOfProducts
# 1    1409
# 2     348
# 3     220
# 4      60
# Name: Exited, dtype: int64

# %%
new_df = pd.DataFrame({
    'Country': ['India', 'Pakistan', 'Germany'],
    'Region': ['Asia', 'Asia', 'Europe']
})

# %%
new_df
# Out:
#     Country  Region
# 0     India    Asia
# 1  Pakistan    Asia
# 2   Germany  Europe

# %%
merge_df = pd.merge(df, new_df, left_on='Geography', right_on='Country', how='left')

# %%
merge_df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
merge_df.groupby('Region')[['Balance','EstimatedSalary']].mean()
# Out:
#               Balance  EstimatedSalary
# Region
# Europe  119730.116134    101113.435102
