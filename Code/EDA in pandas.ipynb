# %%
# data -->
# numerical --> continuous data --> we can devide furthur.
# salary = 20500.60, weight = 70.54, distance(jaipur to delhi)= 270.78km, height, age 
# categorical --. Descreate data --> we cannot devide further. 
# gender(m,f), marritial status(mu), number of employees in an office,

# covid data --> has_covid(y,n) --> map --> (1,0)
# customer cafe --> bill pay --> 453.25 rupees

# %% [markdown]
# PART OF EDA
# 1. univariate analysis --> one variable at a time
# 2. bivariate analysis --> two variable at a time
# 3. multivariate analysis --> more than two variable at a timeA

# %%
import numpy as np
import pandas as pd

# %%
# !pip install matplotlib

# %%
# !pip install seaborn

# %%
import matplotlib.pyplot as plt # Visualization library
import seaborn as sns # matplotlib updated version is seaborn

# %%
df = pd.read_csv('c:\\Users\\SUDHIR FAUJDAR\\Desktop\\Adv python\\EDA-Data-Analysis\\files\\titanic - titanic.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df['Survived'].value_counts()
# Out:
# Survived
# 0    266
# 1    152
# Name: count, dtype: int64

# %%
a = sns.countplot(x = df['Survived'])

# %%
df['Survived'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Survived'>

# %%
df['Survived'].value_counts().plot(kind = 'pie' , autopct = '%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
# If we have numerical data we use histogram
# because it finds the distribution

# %%
plt.hist(x=df['Age'])
plt.show()

# %%
# for finding outlayers
# box plot is used
# sns.boxplot(x = df['Age'])
# 1. Lower fence 
# 2. 25% data
# 3. IQR(Inter Quartile Range)(75% - 25%)
# 4. 75% data
# 5 .upper fence

# %%
# x = 1,2,3,4,5
# mean = (1+2+3+4+5)/5 = 3
# x = 1,2,3,4,5,100
# mean = 15+100/6 = 115/6 = 19.16

# %%
sns.boxplot(x = df['Age'])
# the dots in the output denotes the outlayers in the data.
# Out:
# <Axes: xlabel='Age'>

# %%
# using tips - tips data 
df = pd.read_csv('files/tips - tips.csv')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# another way of loading the database using seaborn library
tips = sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# BIVARIATE ANALYSIS

# %%
# scatterplot (numerical column - numerical column)
sns.scatterplot(x = tips['total_bill'] , y = tips['tip'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x = "total_bill" , y = "tip" , data=tips , hue = tips['sex'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>
