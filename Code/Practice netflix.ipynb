# %%
import pandas as pd 
import seaborn as sea
import matplotlib as ml

# %%
! pip install plotly
# Out:
# Requirement already satisfied: plotly in c:\users\sudhir faujdar\appdata\local\programs\python\python312\lib\site-packages (6.2.0)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\sudhir faujdar\appdata\local\programs\python\python312\lib\site-packages (from plotly) (1.46.0)
# Requirement already satisfied: packaging in c:\users\sudhir faujdar\appdata\local\programs\python\python312\lib\site-packages (from plotly) (25.0)
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import plotly.graph_objects as go
import plotly.io as pio
pio.templates.default = "plotly_white"

# %%
df = pd.read_csv('../files/Netflix.csv')

# %%
df
# Out:
#                                              Title release year ep[isodes  \
# 0                                    1. Our Planet    2019–2023    12 eps
# 1                                2. The Last Dance         2020    10 eps
# 2                              3. When They See Us         2019     4 eps
# 3                                  4. Black Mirror        2011–    34 eps
# 4                                        5. Narcos    2015–2017    30 eps
# ..                                             ...          ...       ...
# 95  96. I Think You Should Leave with Tim Robinson    2019–2023    18 eps
# 96                                         97. You    2018–2025    50 eps
# 97                                        98. Love    2016–2018    34 eps
# 98                                 99. Alias Grace         2017     6 eps
# 99                                100. The Serpent         2021     8 eps
#
#               type  ipc-rating-star--rating ipc-rating-star--voteCount  \
# 0        TV Series                      9.2                      (63K)
# 1   TV Mini Series                      9.0                     (179K)
# 2   TV Mini Series                      8.8                     (158K)
# 3        TV Series                      8.7                     (733K)
# 4        TV Series                      8.7                     (525K)
# ..             ...                      ...                        ...
# 95       TV Series                      8.1                      (26K)
# 96       TV Series                      7.6                     (364K)
# 97       TV Series                      7.6                      (48K)
# 98  TV Mini Series                      7.6                      (42K)
# 99  TV Mini Series                      7.6                      (54K)
#
#                ipc-link production             casting          casting 2  \
# 0   Alastair Fothergill      Stars  David Attenborough                NaN
# 1        Michael Jordan        NaN        Phil Jackson                NaN
# 2          Ava DuVernay      Stars       Asante Blackk      Ethan Herisse
# 3       Charlie Brooker      Stars        Anjana Vasan      Jesse Plemons
# 4         Carlo Bernard      Stars      Chris Brancato       Pedro Pascal
# ..                  ...        ...                 ...                ...
# 95           Zach Kanin      Stars        Tim Robinson     Sam Richardson
# 96        Greg Berlanti      Stars         Sera Gamble  Victoria Pedretti
# 97          Judd Apatow      Stars        Lesley Arfin     Gillian Jacobs
# 98          Sarah Gadon        NaN     Edward Holcroft                NaN
# 99          Tahar Rahim        NaN         Billy Howle                NaN
#
#           casting 2.1
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4        Wagner Moura
# ..                ...
# 95     Patti Harrison
# 96  Charlotte Ritchie
# 97          Paul Rust
# 98                NaN
# 99                NaN
#
# [100 rows x 11 columns]

# %%
df.columns
# Out:
# Index(['Title', 'release year', 'ep[isodes', 'type', 'ipc-rating-star--rating',
#        'ipc-rating-star--voteCount', 'ipc-link', 'production', 'casting',
#        'casting 2', 'casting 2.1'],
#       dtype='object')

# %%
df['type'].value_counts()
# Out:
# type
# TV Series         82
# TV Mini Series    18
# Name: count, dtype: int64

# %%
a =sea.countplot(x = df['type'])

# %%
df['type'].value_counts().plot(kind = 'pie' , autopct = '%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
df.isnull().sum()
# Out:
# Title                          0
# release year                   0
# ep[isodes                      0
# type                           0
# ipc-rating-star--rating        0
# ipc-rating-star--voteCount     0
# ipc-link                       0
# production                    22
# casting                        0
# casting 2                     23
# casting 2.1                   63
# dtype: int64

# %%
net_df = df[df['type'] == 'TV Series']

# %%
net_df
# Out:
#                                              Title release year ep[isodes  \
# 0                                    1. Our Planet    2019–2023    12 eps
# 3                                  4. Black Mirror        2011–    34 eps
# 4                                        5. Narcos    2015–2017    30 eps
# 5                                          6. Dark    2017–2020    26 eps
# 6                               7. Stranger Things    2016–2025    42 eps
# ..                                             ...          ...       ...
# 93                                    94. El Chapo    2017–2018    34 eps
# 94                                  95. Undercover    2019–2022    28 eps
# 95  96. I Think You Should Leave with Tim Robinson    2019–2023    18 eps
# 96                                         97. You    2018–2025    50 eps
# 97                                        98. Love    2016–2018    34 eps
#
#          type  ipc-rating-star--rating ipc-rating-star--voteCount  \
# 0   TV Series                      9.2                      (63K)
# 3   TV Series                      8.7                     (733K)
# 4   TV Series                      8.7                     (525K)
# 5   TV Series                      8.7                     (539K)
# 6   TV Series                      8.6                     (1.7M)
# ..        ...                      ...                        ...
# 93  TV Series                      7.8                      (22K)
# 94  TV Series                      7.8                      (22K)
# 95  TV Series                      8.1                      (26K)
# 96  TV Series                      7.6                     (364K)
# 97  TV Series                      7.6                      (48K)
#
#                ipc-link production             casting          casting 2  \
# 0   Alastair Fothergill      Stars  David Attenborough                NaN
# 3       Charlie Brooker      Stars        Anjana Vasan      Jesse Plemons
# 4         Carlo Bernard      Stars      Chris Brancato       Pedro Pascal
# 5         Baran bo Odar      Stars       Jantje Friese  Karoline Eichhorn
# 6           Matt Duffer      Stars         Ross Duffer      Finn Wolfhard
# ..                  ...        ...                 ...                ...
# 93      Silvana Aguirre      Stars    Carlos Contreras     Humberto Busto
# 94    Bart Uytdenhouwen      Stars      Nico Moolenaar           Tom Waes
# 95           Zach Kanin      Stars        Tim Robinson     Sam Richardson
# 96        Greg Berlanti      Stars         Sera Gamble  Victoria Pedretti
# 97          Judd Apatow      Stars        Lesley Arfin     Gillian Jacobs
#
#           casting 2.1
# 0                 NaN
# 3                 NaN
# 4        Wagner Moura
# 5         Lisa Vicari
# 6        Winona Ryder
# ..                ...
# 93      Diego Vásquez
# 94        Sean Burgos
# 95     Patti Harrison
# 96  Charlotte Ritchie
# 97          Paul Rust
#
# [82 rows x 11 columns]

# %%
grp_by_production = net_df.groupby(['production']).size().reset_index(name = 'count')

# %%
grp_by_production
# Out:
#   production  count
# 0      Stars     70
